# %%
def astaralgo(startnode,endnode):
    open_set=set(startnode)
    closed_set=set()
    g={}
    parent={}
    parent[startnode]=startnode
    g[startnode]=0
    
    while len(open_set)>0:
        n=None
        
        for v in open_set:
            if n==None or g[v]+heu[v]<g[n]+heu[n]:
                n=v
            
        if n==endnode or graph[n]==None: 
            pass
        else:
            for(m,weight) in get_adjacent(n):
                if m not in open_set and m not in closed_set:
                    open_set.add(m)
                    g[m]=g[n]+weight
                    parent[m]=n
                
                else:
                    if g[m]>g[n]+weight:
                        g[m]=g[n]+weight
                        parent[m]=n
                        
                        if m in closed_set:
                            closed_set.remove(m)
                            open_set.add(m)
                            
        if n==None:
            print('Path does not exist.')
        
        if n==endnode:
            path=[]
            
            while parent[n]!=n:
                path.append(n)
                n=parent[n]
                
            path.append(startnode)
            path.reverse()
            
            print('---Path found---')
            return path
        
        open_set.remove(n)
        closed_set.add(n)
        
    print('open set',open_set)
    print('parent',parent)
    print('distance g',g)

def get_adjacent(v):
    if v in graph:
        return graph[v]
    else:
        None

graph={'S':[('A',1),('G',10)],
       'A':[('B',2),('C',1)],
       'B':[('D',5)],
       'C':[('D',3),('G',4)],
       'D':[('G',2)],
       'G':None}
heu={'S':5,'A':3,'B':4,'C':2,'D':6,'G':0}
astaralgo('S','G')
# Out:
# ---Path found---
# ['S', 'A', 'C', 'G']

# %%
def astaralgo(startnode,endnode):
    open_set=set(startnode)
    closed_set=set()
    g={}
    parent={}
    parent[startnode]=startnode
    g[startnode]=0
    
    while len(open_set)>0:
        n=None
        
        for v in open_set:
            if n==None or g[v]+heu[v]<g[n]+heu[n]:
                n=v
            
        if n==endnode or graph[n]==None:
            pass
        else:
            for(m,weight) in get_adjacent(n):
                if m not in open_set and m not in closed_set:
                    open_set.add(m)
                    g[m]=g[n]+weight
                    parent[m]=n
                
                else:
                    if g[m]>g[n]+weight:
                        g[m]=g[n]+weight
                        parent[m]=n
                        
                        if m in closed_set:
                            closed_set.remove(m)
                            open_set.add(m)
                            
        if n==None:
            print('Path does not exist.')
        
        if n==endnode:
            path=[]
            
            while parent[n]!=n:
                path.append(n)
                n=parent[n]
                
            path.append(startnode)
            path.reverse()
            
            print('---Path found---')
            return path
        
        open_set.remove(n)
        closed_set.add(n)
        
    print('open set',open_set)
    print('parent',parent)
    print('distance g',g)

def get_adjacent(v):
    if v in graph:
        return graph[v]
    else:
        None

graph={'S':[('A',1),('G',10)],
       'A':[('B',2),('C',1)],
       'B':[('D',5)],
       'C':[('D',3),('G',4)],
       'D':[('G',2)],
       'G':None}
heu={'S':5,'A':3,'B':4,'C':2,'D':6,'G':0}
astaralgo('S','D')
# Out:
# ---Path found---
# ['S', 'A', 'C', 'D']

# %%
def astaralgo(startnode,endnode):
    open_set=set(startnode)
    closed_set=set()
    g={}
    parent={}
    parent[startnode]=startnode
    g[startnode]=0
    
    while len(open_set)>0:
        n=None
        
        for v in open_set:
            if n==None or g[v]+heu[v]<g[n]+heu[n]:
                n=v
            
        if n==endnode or graph[n]==None:
            pass
        else:
            for(m,weight) in get_adjacent(n):
                if m not in open_set and m not in closed_set:
                    open_set.add(m)
                    g[m]=g[n]+weight
                    parent[m]=n
                
                else:
                    if g[m]>g[n]+weight:
                        g[m]=g[n]+weight
                        parent[m]=n
                        
                        if m in closed_set:
                            closed_set.remove(m)
                            open_set.add(m)
                            
        if n==None:
            print('Path does not exist.')
        
        if n==endnode:
            path=[]
            
            while parent[n]!=n:
                path.append(n)
                n=parent[n]
                
            path.append(startnode)
            path.reverse()
            
            print('---Path found---')
            return path
        
        open_set.remove(n)
        closed_set.add(n)
        
    print('open set',open_set)
    print('parent',parent)
    print('distance g',g)

def get_adjacent(v):
    if v in graph:
        return graph[v]
    else:
        None

graph={'S':[('A',1),('G',10)],
       'A':[('B',2),('C',1)],
       'B':[('D',5)],
       'C':[('D',3),('G',4)],
       'D':[('G',2)],
       'G':None}
heu={'S':5,'A':3,'B':4,'C':2,'D':6,'G':0}
astaralgo('S')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/27/b3js4v5n1410hjf69hvj31d40000gn/T/ipykernel_1721/567156066.py in <module>
#      68        'G':None}
#      69 heu={'S':5,'A':3,'B':4,'C':2,'D':6,'G':0}
# ---> 70 astaralgo('S')
#
# TypeError: astaralgo() missing 1 required positional argument: 'endnode'

# %%
def astaralgo(startnode,endnode):
    open_set=set(startnode)
    closed_set=set()
    g={}
    parent={}
    parent[startnode]=startnode
    g[startnode]=0
    
    while len(open_set)>0:
        n=None
        
        for v in open_set:
            if n==None or g[v]+heu[v]<g[n]+heu[n]:
                n=v
            
        if n==endnode or graph[n]==None: 
            pass
        else:
            for(m,weight) in get_adjacent(n):
                if m not in open_set and m not in closed_set:
                    open_set.add(m)
                    g[m]=g[n]+weight
                    parent[m]=n
                
                else:
                    if g[m]>g[n]+weight:
                        g[m]=g[n]+weight
                        parent[m]=n
                        
                        if m in closed_set:
                            closed_set.remove(m)
                            open_set.add(m)

        if n==endnode:
            path=[]
            
            while parent[n]!=n:
                path.append(n)
                n=parent[n]
                
            path.append(startnode)
            path.reverse()
            
            print('---Path found---')
            return path
        
        open_set.remove(n)
        closed_set.add(n)
    
    
    print('Path does not exist.')
    
    print('open set \n',open_set)
    print('parent',parent)
    print('distance g',g)

def get_adjacent(v):
    if v in graph:
        return graph[v]
    else:
        None

graph={'S':[('A',1),('C',10)],
       'A':None,
       'C':None,
       'G':None}

'''graph={'S':[('A',1),('G',10)],
       'A':[('B',2),('C',1)],
       'B':[('D',5)],
       'C':[('D',3),('G',4)],
       'D':[('G',2)],
       'G':None}'''
heu={'S':5,'A':3,'B':4,'C':2,'D':6,'G':0}
astaralgo('S','G')
# Out:
# Path does not exist.
# open set
#  set()
# parent {'S': 'S', 'A': 'S', 'C': 'S'}
# distance g {'S': 0, 'A': 1, 'C': 10}

# %%
def astaralgo(startnode,endnode):
    open_set=list(startnode)
    closed_set=set()
    g={}
    parent={}
    parent[startnode]=startnode
    g[startnode]=0
    
    while len(open_set)>0:
        n=None
        
        for v in open_set:
            if n==None or g[v]+heu[v]<g[n]+heu[n]:
                n=v
            
        if n==endnode or graph[n]==None: 
            pass
        else:
            for(m,weight) in get_adjacent(n):
                if m not in open_set and m not in closed_set:
                    open_set.append(m)
                    g[m]=g[n]+weight
                    parent[m]=n
                
                else:
                    if g[m]>g[n]+weight:
                        g[m]=g[n]+weight
                        parent[m]=n
                        
                        if m in closed_set:
                            closed_set.remove(m)
                            open_set.append(m)
                            
            
        
        if n==endnode:
            path=[]
            
            while parent[n]!=n:
                path.append(n)
                n=parent[n]
                
            path.append(startnode)
            path.reverse()
            
            print('---Path found---')
            return path
        print('open set',open_set)
        print('parent',parent)
        print('distance g',g)

        open_set.remove(n)
        #open_set.remove(n)
        closed_set.add(n)
    print('Path does not exist.')    
    
def get_adjacent(v):
    if v in graph:
        return graph[v]
    else:
        None

graph={'A':[('B',4),('C',7)],
       'B':[('D',5)],
       'C':[('D',6)],
       'D':None}
heu={'A':8,'B':3,'C':2,'D':0}
astaralgo('A','D')
# Out:
# open set ['A', 'B', 'C']
# parent {'A': 'A', 'B': 'A', 'C': 'A'}
# distance g {'A': 0, 'B': 4, 'C': 7}
# open set ['B', 'C', 'D']
# parent {'A': 'A', 'B': 'A', 'C': 'A', 'D': 'B'}
# distance g {'A': 0, 'B': 4, 'C': 7, 'D': 9}
# open set ['C', 'D']
# parent {'A': 'A', 'B': 'A', 'C': 'A', 'D': 'B'}
# distance g {'A': 0, 'B': 4, 'C': 7, 'D': 9}
# ---Path found---
# ['A', 'B', 'D']
